# %%
import pandas as pd

# %%
df = pd.read_csv('data/cdc_firearm_deaths.csv')
df.sort_values('RATE', ascending=False).reset_index()
# Out:
#     index  YEAR STATE  RATE  DEATHS  \
# 0      23  2020    MS  28.6     818
# 1      17  2020    LA  26.3    1183
# 2      49  2020    WY  25.9     154
# 3      24  2020    MO  23.9    1426
# 4       0  2020    AL  23.6    1141
# 5       1  2020    AK  23.5     175
# 6      30  2020    NM  22.7     479
# 7       3  2020    AR  22.6     673
# 8      39  2020    SC  22.0    1131
# 9      41  2020    TN  21.3    1473
# 10     25  2020    MT  20.9     238
# 11     35  2020    OK  20.7     826
# 12     16  2020    KY  20.1     902
# 13     47  2020    WV  18.1     325
# 14      9  2020    GA  17.7    1897
# 15     11  2020    ID  17.6     321
# 16     13  2020    IN  17.3    1159
# 17     27  2020    NV  17.0     547
# 18     15  2020    KS  16.9     494
# 19      2  2020    AZ  16.7    1265
# 20     32  2020    NC  16.0    1699
# 21      5  2020    CO  15.4     922
# 22     34  2020    OH  15.2    1764
# 23     21  2020    MI  14.6    1454
# 24      7  2020    DE  14.4     135
# ...
